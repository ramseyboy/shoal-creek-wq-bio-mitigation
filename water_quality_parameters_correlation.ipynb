# %%
import warnings
import geopandas
import pandas

warnings.filterwarnings('ignore')
geopandas.options.io_engine = "pyogrio"
# %matplotlib inline

from plotting import plot_correlation, plot_parameter
import intervals

parameters = [
    "turbidity",
    "conductivity",
    "ecoli"
]

project_parameters = intervals.joined_parameters_query(parameters, intervals.locations_query())
project_parameters
# Out:
#      avg_value_turbidity  median_value_turbidity  max_value_turbidity  \
# 0                  80.00                   80.00                80.00
# 1                   3.45                    3.45                 3.50
# 2                1650.00                 1800.00              2700.00
# 3                1135.00                  845.00              2600.00
# 4                    NaN                     NaN                  NaN
# ..                   ...                     ...                  ...
# 129                13.00                   13.00                13.00
# 130                  NaN                     NaN                  NaN
# 131                 1.11                    1.11                 1.26
# 132                  NaN                     NaN                  NaN
# 133                  NaN                     NaN                  NaN
#
#      min_value_turbidity start_date  avg_value_conductivity  \
# 0                  80.00 1980-04-25                 282.000
# ...

# %%
plot_correlation(project_parameters, title="")
# Out:
#                            avg_value_turbidity  median_value_turbidity  \
# avg_value_turbidity                   1.000000                0.995570
# median_value_turbidity                0.995570                1.000000
# max_value_turbidity                   0.990578                0.984218
# min_value_turbidity                   0.663754                0.673092
# avg_value_conductivity               -0.491718               -0.492307
# median_value_conductivity            -0.489888               -0.489617
# max_value_conductivity               -0.394662               -0.397740
# min_value_conductivity               -0.569030               -0.567384
# avg_value_ecoli                       0.728135                0.724462
# median_value_ecoli                    0.717750                0.724688
# max_value_ecoli                       0.740293                0.731050
# min_value_ecoli                       0.511754                0.524932
#
# ...
